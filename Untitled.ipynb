# %%
import plot_logfun

# %%
plot_logfun.plot_trajectory(n=4, r=2.2, x0=0.1)
# Out:
# (<Figure size 720x360 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f562f79b9d0>)

# %%
plot_logfun.plot_trajectory(n=4, r=3.4, x0=0.2)
# Out:
# (<Figure size 720x360 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f562f70d610>)
